# %% [markdown]
# # random Investment

# %% [markdown]
# - list 1
#     - sublist

# %% [markdown]
# $y = c_0 + c_1*x+c_2*x^2$

# %%
import pandas as pd
import numpy  as np 

import matplotlib.pyplot as plt


import seaborn as sns
# constants are unknown  hence, linear regression,
# Out:
# /var/folders/qx/vfr8b98x3m96_l4x2q960pwm0000gn/T/ipykernel_5617/3112930398.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # load the investment#

# %%
# load the csv file 
Invest = pd.read_csv('final_transactions_dataset.csv')

# %%
Invest1 = Invest[0:200000]

# %%
print(Invest.shape[1])

Invest[0:Invest.shape[1]]
# Out:
# 25
#     Unnamed: 0 company  sector  horizon (days)  amount date_BUY_fix  \
# 0            0     BBY  RETAIL               2     100   2017-05-25
# 1            1     BAC    BANK             330   15000   2016-11-22
# 2            2     AXP    BANK               7    3000   2016-09-27
# 3            3     KSS  RETAIL               5   20000   2016-10-11
# 4            4     JPM    BANK             360   15000   2015-03-12
# 5            5     PEP    FMCG              15   50000   2016-09-09
# 6            7      FB    TECH             720    1500   2014-11-12
# 7            8     UBS    BANK             600     300   2016-02-26
# 8            9     BAC    BANK              30   50000   2015-07-16
# 9           10     JPM    BANK               6     400   2016-02-10
# 10          11     BBY  RETAIL               2      50   2016-03-04
# 11          13      DB    BANK             480     200   2015-04-06
# 12          14     AXP    BANK               6   10000   2015-05-01
# ...

# %%
#normalizaingtion is a must, for all algorthimns, min, max, normalizing or not, min-max, predictor, raw data cannot be fed into the model. data understanding is, output ,more than two class, Deep learning, in images it is automatically normalized,easier to work with image re-usable

# %%
# abundant netwrok, deep netwrok more observation, regression tree: ML when less data and infrastructure, random ,regression, neural network. 

# neurons is a logit, each neuron logistic regression: sigmoind function as activation, sigmoid, less than zero is relu, sigmoind, also goes negative, single logit, single neuron, logistic regression, used to classify, question is gneral regreession numerical logistic regression, even  if it is used as classification, reasonL gives numerical value but using 0-1 , regression it can be, personal project, journey of personal project, why approach and process, explain. what problem statemnt I , how , and why.

# %%
Invest1 = Invest[0:200000]

# %% [markdown]
# Invest1[0:100]

# %%
# add explaanation of atributes

# %%
#sns.pairplot(Invest1)

# %%
Return = Invest1['nominal_return']

# %%
Invest1.describe()
# Out:
#           Unnamed: 0  horizon (days)         amount      price_BUY  \
# count  200000.000000   200000.000000  200000.000000  200000.000000
# mean   123412.420690      187.489230    8118.344250     104.816776
# std     71186.023736      211.056472   12802.949893     216.410890
# min         0.000000        1.000000      50.000000       7.137111
# 25%     61835.750000       15.000000     400.000000      28.229881
# 50%    123451.500000       90.000000    2000.000000      46.137466
# 75%    185064.500000      300.000000   10000.000000      76.075722
# max    246671.000000      720.000000   50000.000000    2039.510010
#
#           price_SELL  Volatility_Buy  Volatility_sell   Sharpe Ratio  \
# count  200000.000000   200000.000000    200000.000000  200000.000000
# mean      116.319366        0.254446         0.260056       0.254446
# std       249.837991        0.097985         0.099284       0.097985
# min         4.010000        0.090416         0.090416       0.090416
# ...

# %% [markdown]
# #  explanation of dropping attributes
# #assumptions and

# %%
Invest2 = Invest1.drop(['NetProfitMargin_ratio','expected_return (yearly)','nominal_return','Unnamed: 0','company','sector','date_BUY_fix','date_SELL_fix','price_SELL','Volatility_sell','investment','Sharpe Ratio','PE_ratio','PS_ratio','PB_ratio'], axis = 1)

#  attribures nonnumerical datatypes to fit with neural network as well as attributes like the Sharpe_Ratio which calculated using the ouptut are removed

# %%
Invest2
print(Invest2.shape[0])
# Out:
# 200000

# %%
Return
# Out:
# 0        -0.037225
# 1         0.324317
# 2        -0.005756
# 3        -0.058388
# 4         0.003444
#             ...
# 199995   -0.051145
# 199996   -0.078845
# 199997    0.326308
# 199998    0.136835
# 199999    0.035928
# Name: nominal_return, Length: 200000, dtype: float64

# %%
Invest
# Out:
#         Unnamed: 0 company  sector  horizon (days)  amount date_BUY_fix  \
# 0                0     BBY  RETAIL               2     100   2017-05-25
# 1                1     BAC    BANK             330   15000   2016-11-22
# 2                2     AXP    BANK               7    3000   2016-09-27
# 3                3     KSS  RETAIL               5   20000   2016-10-11
# 4                4     JPM    BANK             360   15000   2015-03-12
# ...            ...     ...     ...             ...     ...          ...
# 405253      499992      GM    AUTO             480   50000   2014-06-02
# 405254      499994      SC    BANK             300   50000   2016-03-10
# 405255      499996     HOG    AUTO             210    3000   2016-05-31
# 405256      499998    AAPL    TECH             270     500   2017-12-21
# 405257      499999      KO    FMCG              15    2000   2014-10-20
#
#        date_SELL_fix  price_BUY  price_SELL  Volatility_Buy  ...  investment  \
# ...

# %%
Invest2
# Out:
#         horizon (days)  amount  price_BUY  Volatility_Buy  inflation  \
# 0                    2     100  55.551804        0.383666       1.96
# 1                  330   15000  18.616749        0.322809      -0.20
# 2                    7    3000  59.862297        0.238642      -0.20
# 3                    5   20000  38.216724        0.428559      -0.20
# 4                  360   15000  51.869335        0.194612      -0.50
# ...                ...     ...        ...             ...        ...
# 199995             120     500  28.741871        0.224747      -0.50
# 199996             150    1500  28.542963        0.242287      -0.15
# 199997             270    1500  58.351299        0.253744      -0.20
# 199998              90    2000  30.840000        0.191505      -0.50
# 199999              80    4000  17.665504        0.525184      -0.20
#
#         ESG_ranking  EPS_ratio  current_ratio  roa_ratio  roe_ratio
# 0              12.0       3.73           1.49       8.69      26.69
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
Invest2_scaled = scaler.fit_transform(Invest2) #activation function of neural layer is   relu requires inputs from -1 to 1 

Return = Return.values.reshape(-1,1) # in order to allow for the 
Return_scaled = scaler.fit_transform(Return)

# %%
from sklearn.model_selection import train_test_split 
Invest2_train, Invest2_test, Return_train, Return_test = train_test_split(Invest2_scaled, Return_scaled, test_size = 0.25, random_state = 10)


#Invest2_valtrain, Invest2_valtrain, Return_valtrain, Return_valtest = train_test_split(Invest2_scaled, Return_scaled, test_size = 0.20, random_state = 10)

# %%
Invest2_train.shape
# Out:
# (150000, 10)

# %%
Invest2_train
# Out:
# array([[0.33240612, 0.001001  , 0.01141173, ..., 0.04787645, 0.32550861,
#         0.69369657],
#        [0.12378303, 0.        , 0.00190402, ..., 0.04864865, 0.32609546,
#         0.81989282],
#        [0.00139082, 0.05905906, 0.02870999, ..., 0.02162162, 0.40864632,
#         0.75826209],
#        ...,
#        [0.00834492, 0.1991992 , 0.03372581, ..., 0.03783784, 0.41040689,
#         0.74237591],
#        [0.10987483, 0.00900901, 0.37338762, ..., 0.03397683, 0.32022692,
#         0.72323593],
#        [0.45757997, 0.02902903, 0.05312159, ..., 0.85559846, 0.54929577,
#         0.74135511]])

# %%
import tensorflow.keras 
from keras.models import Sequential 
from keras.layers import Dense
from sklearn.preprocessing import MinMaxScaler
model = Sequential()

model.add(Dense(20, input_dim = 10, activation = 'relu'))
model.add(Dense(22, activation='relu'))
model.add(Dense(5, activation='relu'))
model.add(Dense(1, activation='linear'))# outputs a single value value and compatible with regression
model.summary()
# Out:
# 2024-10-21 19:04:32.209803: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# ...

# %%
model.compile(optimizer = "adam", loss = 'mean_squared_error') 
# adam optimizer because it is shown to have the best efficiency when it comes to training a model compared to other optimizers

# %%
Return_scaled
# Out:
# array([[0.08491499],
#        [0.12215403],
#        [0.08815627],
#        ...,
#        [0.12235918],
#        [0.10284329],
#        [0.09244977]])

# %%
Invest
#
# Out:
#         Unnamed: 0 company  sector  horizon (days)  amount date_BUY_fix  \
# 0                0     BBY  RETAIL               2     100   2017-05-25
# 1                1     BAC    BANK             330   15000   2016-11-22
# 2                2     AXP    BANK               7    3000   2016-09-27
# 3                3     KSS  RETAIL               5   20000   2016-10-11
# 4                4     JPM    BANK             360   15000   2015-03-12
# ...            ...     ...     ...             ...     ...          ...
# 405253      499992      GM    AUTO             480   50000   2014-06-02
# 405254      499994      SC    BANK             300   50000   2016-03-10
# 405255      499996     HOG    AUTO             210    3000   2016-05-31
# 405256      499998    AAPL    TECH             270     500   2017-12-21
# 405257      499999      KO    FMCG              15    2000   2014-10-20
#
#        date_SELL_fix  price_BUY  price_SELL  Volatility_Buy  ...  investment  \
# ...

# %%
Invest2
# Out:
#         horizon (days)  amount  price_BUY  Volatility_Buy  inflation  \
# 0                    2     100  55.551804        0.383666       1.96
# 1                  330   15000  18.616749        0.322809      -0.20
# 2                    7    3000  59.862297        0.238642      -0.20
# 3                    5   20000  38.216724        0.428559      -0.20
# 4                  360   15000  51.869335        0.194612      -0.50
# ...                ...     ...        ...             ...        ...
# 199995             120     500  28.741871        0.224747      -0.50
# 199996             150    1500  28.542963        0.242287      -0.15
# 199997             270    1500  58.351299        0.253744      -0.20
# 199998              90    2000  30.840000        0.191505      -0.50
# 199999              80    4000  17.665504        0.525184      -0.20
#
#         ESG_ranking  EPS_ratio  current_ratio  roa_ratio  roe_ratio
# 0              12.0       3.73           1.49       8.69      26.69
# ...

# %%
tensorflow.keras.utils.set_random_seed(381)

# %%
 epoch_hist= model.fit( Invest2_train, Return_train,  epochs = 30 , batch_size = 10000, verbose = 1, validation_split = 0.20)
 #epoch_hist= model.fit( Invest2_train, Return_train,epochs = 30, batch_size = 25, verbose = 1, valdiation_split=0.20)
# Out:
# Epoch 1/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0059 - val_loss: 0.0024
# Epoch 2/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 3/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 4/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 5/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 6/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0010 - val_loss: 9.5911e-04
# Epoch 7/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - val_loss: 9.2422e-04
# Epoch 8/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.6801e-04 - val_loss: 8.9704e-04
# Epoch 9/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.4145e-04 - val_loss: 8.7171e-04
# Epoch 10/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.1660e-04 - val_loss: 8.4737e-04
# Epoch 11/30
# ...

# %%
 #epoch_hist= model.fit( Invest2_train, Return_train, epochs = 29, batch_size = 100, verbose = 1, validation_split = 0.3)

# %%
print(Invest2_train.shape[0])
# Out:
# 150000

# %%
epoch_hist.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(epoch_hist.history['loss'])

plt.plot(epoch_hist.history['val_loss'])
plt.legend(['Training loss',' Validation loss'])

#

# %%
testing=model.evaluate(Invest2_test, Return_test, verbose=1)
# Out:
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 767us/step - loss: 7.5917e-04

# %%
plt.plot(epoch_hist.history['loss'])

plt.plot(epoch_hist.history['val_loss'])
plt.legend(['Training loss',' Validation loss'])
plt.plot(testing)
plt.legend(['Training loss',' Validation loss','testing'])
